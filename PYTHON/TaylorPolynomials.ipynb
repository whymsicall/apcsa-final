# %% [markdown]
# ## Taylor Polynomials for Non-Polynomial Functions -- Applied Calculus

# %% [markdown]
# If we consider a function $f$ with derivatives of all orders, then the power series generated for $f$ at $x=c$ can be expressed as:
# $$f(x) \approx f(c)+\cfrac{f^{(1)}(c)}{1!}(x-c)+ \cfrac{f^{(2)}(c)}{2!}(x-c)^2 +\cdots + \cfrac{f^{(n)}(c)}{n!}(x-c)^n +\cdots  $$
#
# Since this is a long and ongoing sum, we call it an infinite series.  In general mathematics, the uppercase $S$ in Greek is used as an operator for summation: $$ \sum - sigma$$
#
# The Taylor polynomial of order $n$ generated by $f$ at $x=c$ is the polynomial
# 	$$P_n(x)=f(c)+f'(c)(x-c)+\cfrac{f^{''}(c)}{2!}(x-c)^2 +\cdots + \cfrac{f^{(n)}(c)}{n!}(x-c)^n$$
# Note that a Taylor Series is infinite, meanwhile a Taylor Polynomial is of finite degree. Clearly, it is not useful to express functions as infinite sums because we cannot even compute them that way (not even a power computer). However, it is often useful to approximate functions by using a Taylor Polynomial.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# In order to plot the sin function along with the first, third, fifth, and seventh order Taylor Polynomial approximations we have provided the following code. Note that this is the zero-th to third in the formula given earlier.

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))

labels = ['First Order', 'Third Order', 'Fifth Order', 'Seventh Order']

plt.figure(figsize = (10,8))
for n, label in zip(range(4), labels):
    y = y + ((-1)**n * (x)**(2*n+1)) / np.math.factorial(2*n+1)
    plt.plot(x,y, label = label)

plt.plot(x, np.sin(x), 'k', label = 'Analytic Sine') ##actual graph
plt.grid()
plt.title('Taylor Series Approximations of Various Orders')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# As you can see, the approximation approaches the analytic function quickly, even for $x$
#  not near to $a=0$.  Note that in the above code, we also used a new function - 'zip', which can allow us to loop through two parameters range(4) and labels and use that in our plot.

# %% [markdown]
# In order to check how precise each polynomial is, wecompute the seventh order Taylor series approximation for $\sin(x)$
# around $a=0$ at $x=\cfrac{\pi}{2}$ and compare the value to the correct value, 1.

# %%
x = np.pi/2
y = 0
z = 0
s = 0

for n in range(4): #note how 4 is equivalent to the 7th degree polynomial for sin(x) as n=3 is the final entry
    y = y + ((-1)**n * (x)**(2*n+1)) / np.math.factorial(2*n+1)

print(y)
# Out:
# 0.9998431013994987

# %% [markdown]
# The most common Taylor series approximation is the first order approximation, or linear approximation. Intuitively, for “smooth” functions the linear approximation of the function around a point, 𝑎
# , can be made as good as you want provided you stay sufficiently close to 𝑎
# . In other words, “smooth” functions look more and more like a line the more you zoom into any point. This fact is depicted in the following figure, which we plot successive levels of zoom of a smooth function to illustrate the linear nature of functions locally. Linear approximations are useful tools when analyzing complicated functions locally.

# %% [markdown]
# ## Tasks:

# %% [markdown]
# Write a code that will graph the Taylor Polynomials for $\cos(x)$, $e^x$, and $ln(1+x)$.  Ensure it includes the original function and 4 Taylor Polynomials (of degrees of your choice) with the degree marked.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function definitions
def cos_taylor(x, degree):
    return np.cos(0) + np.sum((-1)**k * x**(2*k) / np.math.factorial(2*k) for k in range(1, degree+1))

def exp_taylor(x, degree):
    return np.sum(x**k / np.math.factorial(k) for k in range(degree+1))

def log_taylor(x, degree):
    return np.sum((-1)**(k-1) * x**k / k for k in range(1, degree+1))

# Generate x values
x_values = np.linspace(-2*np.pi, 2*np.pi, 400)

# Plot original functions
plt.figure(figsize=(15, 10))

# Plot cos(x) and its Taylor polynomials
plt.subplot(3, 1, 1)
plt.plot(x_values, np.cos(x_values), label='cos(x)', linewidth=2)
for degree in range(1, 5):
    plt.plot(x_values, [cos_taylor(x, degree) for x in x_values], label=f'Taylor Degree {degree}')
plt.title('Taylor Polynomials for cos(x)')
plt.legend()

# Plot e^x and its Taylor polynomials
plt.subplot(3, 1, 2)
plt.plot(x_values, np.exp(x_values), label='e^x', linewidth=2)
for degree in range(1, 5):
    plt.plot(x_values, [exp_taylor(x, degree) for x in x_values], label=f'Taylor Degree {degree}')
plt.title('Taylor Polynomials for e^x')
plt.legend()

# Plot ln(1+x) and its Taylor polynomials
plt.subplot(3, 1, 3)
plt.plot(x_values, np.log(1+x_values), label='ln(1+x)', linewidth=2)
for degree in range(1, 5):
    plt.plot(x_values, [log_taylor(x, degree) for x in x_values], label=f'Taylor Degree {degree}')
plt.title('Taylor Polynomials for ln(1+x)')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-1-b0d046e778b4>:6: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return np.cos(0) + np.sum((-1)**k * x**(2*k) / np.math.factorial(2*k) for k in range(1, degree+1))
# <ipython-input-1-b0d046e778b4>:9: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return np.sum(x**k / np.math.factorial(k) for k in range(degree+1))
# <ipython-input-1-b0d046e778b4>:38: RuntimeWarning: invalid value encountered in log
#   plt.plot(x_values, np.log(1+x_values), label='ln(1+x)', linewidth=2)
# <ipython-input-1-b0d046e778b4>:12: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# ...
